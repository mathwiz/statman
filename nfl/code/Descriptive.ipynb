# %%
import pandas as pd

# %%
import statistics as s

# %%
data = pd.read_csv("../data/games/betting.csv")

# %%
len(data)
# Out:
# 9262

# %%
data.iloc[1000:1016,15:35]
# Out:
#       home_recent_scoring  away_recent_scoring  home_scoring_dev  \
# 1000                 18.4                 23.6             6.878
# 1001                 29.2                 22.2             7.576
# 1002                 25.4                  9.6             9.806
# 1003                 13.6                 19.8             7.983
# 1004                 13.4                 28.6             7.546
# 1005                 14.2                 14.4             7.687
# 1006                 16.4                 23.6            10.843
# 1007                 14.2                 31.2             9.543
# 1008                 27.2                 18.2            10.988
# 1009                 13.8                 21.4             7.876
# 1010                 34.2                 14.0             7.426
# 1011                 26.6                 17.8             9.158
# 1012                 12.2                 22.4             9.103
# 1013                 20.8                 26.6             7.218
# 1014                 24.8                 17.0             9.721
# 1015                 21.4                 12.6            11.500
#
#       away_scoring_dev  home_recent_allowed  away_recent_allowed  \
# 1000             9.996                 33.4                 17.0
# 1001            12.067                 17.2                 25.6
# 1002            11.307                 19.8                 13.8
# 1003             7.512                 18.0                 13.8
# 1004            10.668                 17.0                 34.6
# 1005            10.124                 20.8                 18.2
# 1006            12.498                 28.4                 29.8
# 1007            14.727                 23.6                 28.0
# 1008             9.138                 14.4                 19.0
# 1009            13.307                 18.4                 17.4
# 1010             7.395                 18.4                 17.4
# 1011            11.005                 33.8                 23.4
# 1012             8.198                 26.6                 27.8
# 1013            14.729                 12.2                 25.6
# 1014            11.099                 16.8                 21.0
# 1015             9.374                 13.8                 23.6
#
#       home_allowed_dev  away_allowed_dev neutral  playoff  score_home  \
# 1000            11.522            13.319    Home  Regular          34
# 1001            11.844            12.285    Home  Regular          24
# 1002            11.851            12.011    Home  Regular           7
# 1003            11.955            12.315    Home  Regular          13
# 1004            13.547            11.044    Home  Regular          12
# 1005             8.762             9.250    Home  Regular          17
# 1006            11.224            11.959    Home  Regular          41
# 1007            10.980            10.268    Home  Regular           9
# 1008             9.510             9.750    Home  Regular          34
# 1009            11.527             8.948    Home  Regular          20
# 1010            10.695            13.078    Home  Regular          31
# 1011             8.635            10.884    Home  Regular          31
# 1012             9.723            11.078    Home  Regular          20
# 1013            11.940            11.142    Home  Regular          23
# 1014            13.310            10.588    Home  Regular          30
# 1015            10.296            11.166    Home  Regular          23
#
#       score_away home_win   fav_win      cover  spread_diff over_under_result  \
# 1000          27     Home  Underdog  Not Cover        -13.5              Over
# 1001          34     Away  Underdog  Not Cover        -19.0              Over
# 1002          21     Away  Underdog  Not Cover        -20.5             Under
# 1003          19     Away  Underdog  Not Cover         -9.0             Under
# 1004          17     Away  Favorite      Cover          2.0             Under
# 1005          20     Away  Underdog  Not Cover         -4.0              Over
# 1006          38     Home  Favorite  Not Cover         -1.0              Over
# 1007          12     Away  Favorite  Not Cover         -1.0             Under
# 1008          14     Home  Favorite      Cover         12.0              Over
# 1009          14     Home  Underdog  Not Cover         -9.0             Under
# 1010          22     Home  Favorite  Not Cover         -6.5              Over
# 1011          14     Home  Favorite      Cover         16.0              Over
# 1012          10     Home  Favorite      Cover          6.0             Under
# 1013          21     Home  Underdog  Not Cover         -3.0              Over
# 1014          17     Home  Favorite      Cover         10.0              Over
# 1015          20     Home  Favorite  Not Cover         -7.0              Over
#
#       over_under_diff
# 1000             16.0
# 1001             10.5
# 1002            -13.0
# 1003             -7.5
# 1004            -11.0
# 1005              1.5
# 1006             25.5
# 1007            -26.0
# 1008              6.5
# 1009             -4.5
# 1010              8.5
# 1011              1.5
# 1012            -10.5
# 1013              1.0
# 1014              8.5
# 1015              3.5

# %%
data['over_under_diff'].describe()
# Out:
# count    9262.000000
# mean        0.619337
# std        13.682436
# min       -39.000000
# 25%        -9.000000
# 50%         0.000000
# 75%         9.500000
# max        68.500000
# Name: over_under_diff, dtype: float64

# %%
data['over_under_result'].describe()
# Out:
# count      9084
# unique        2
# top       Under
# freq       4605
# Name: over_under_result, dtype: object

# %%
data['spread_diff'].describe()
# Out:
# count    9121.00000
# mean       -0.12071
# std        13.38869
# min       -52.00000
# 25%        -8.50000
# 50%        -0.50000
# 75%         8.50000
# max        50.50000
# Name: spread_diff, dtype: float64

# %%
data['cover'].describe()
# Out:
# count          9262
# unique            2
# top       Not Cover
# freq           4971
# Name: cover, dtype: object

# %%
data['score_home'].describe()
# Out:
# count    9262.000000
# mean       22.490067
# std        10.340737
# min         0.000000
# 25%        15.000000
# 50%        22.000000
# 75%        29.000000
# max        62.000000
# Name: score_home, dtype: float64

# %%
data['score_away'].describe()
# Out:
# count    9262.000000
# mean       19.797020
# std        10.044907
# min         0.000000
# 25%        13.000000
# 50%        20.000000
# 75%        27.000000
# max        59.000000
# Name: score_away, dtype: float64

# %%
data['home_scoring_dev'].describe()
# Out:
# count    7502.000000
# mean        9.053034
# std         3.027619
# min         0.000000
# 25%         7.211000
# 50%         9.056000
# 75%        10.816250
# max        27.577000
# Name: home_scoring_dev, dtype: float64

# %%
data['home_allowed_dev'].describe()
# Out:
# count    7502.000000
# mean        9.312001
# std         3.144480
# min         0.000000
# 25%         7.411250
# 50%         9.311000
# 75%        11.172500
# max        28.991000
# Name: home_allowed_dev, dtype: float64
