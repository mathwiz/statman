# %%
import pandas as pd

# %%
data = pd.read_csv("../data/games/betting.csv")

# %%
len(data)
# Out:
# 9486

# %%
data.head(20)
# Out:
#           date  season  week             home_team  home_wins  \
# 0   09/02/1978    1978     1  Tampa Bay Buccaneers          0
# 1   09/03/1978    1978     1       Atlanta Falcons          0
# 2   09/03/1978    1978     1         Buffalo Bills          0
# 3   09/03/1978    1978     1         Chicago Bears          0
# 4   09/03/1978    1978     1    Cincinnati Bengals          0
# 5   09/03/1978    1978     1      Cleveland Browns          0
# 6   09/03/1978    1978     1        Denver Broncos          0
# 7   09/03/1978    1978     1         Detroit Lions          0
# 8   09/03/1978    1978     1  New England Patriots          0
# 9   09/03/1978    1978     1    New Orleans Saints          0
# 10  09/03/1978    1978     1         New York Jets          0
# 11  09/03/1978    1978     1   Philadelphia Eagles          0
# 12  09/03/1978    1978     1      Seattle Seahawks          0
# 13  09/04/1978    1978     1        Dallas Cowboys          0
# 14  09/09/1978    1978     2  Tampa Bay Buccaneers          0
# 15  09/10/1978    1978     2       Baltimore Colts          0
# 16  09/10/1978    1978     2         Buffalo Bills          0
# 17  09/10/1978    1978     2      Cleveland Browns          0
# 18  09/10/1978    1978     2     Green Bay Packers          0
# 19  09/10/1978    1978     2    Kansas City Chiefs          0
#
#               away_team  away_wins  home_last_season_wins  \
# 0       New York Giants          0                    NaN
# 1        Houston Oilers          0                    NaN
# 2   Pittsburgh Steelers          0                    NaN
# 3   St. Louis Cardinals          0                    NaN
# 4    Kansas City Chiefs          0                    NaN
# 5   San Francisco 49ers          0                    NaN
# 6       Oakland Raiders          0                    NaN
# 7     Green Bay Packers          0                    NaN
# 8   Washington Redskins          0                    NaN
# 9     Minnesota Vikings          0                    NaN
# 10       Miami Dolphins          0                    NaN
# 11     Los Angeles Rams          0                    NaN
# 12   San Diego Chargers          0                    NaN
# 13      Baltimore Colts          0                    NaN
# 14        Detroit Lions          0                    NaN
# 15       Miami Dolphins          0                    NaN
# 16        New York Jets          0                    NaN
# 17   Cincinnati Bengals          0                    NaN
# 18   New Orleans Saints          0                    NaN
# 19       Houston Oilers          0                    NaN
#
#     away_last_season_wins              favorite       ...        neutral  \
# 0                     NaN  Tampa Bay Buccaneers       ...          False
# 1                     NaN                   NaN       ...          False
# 2                     NaN                   NaN       ...          False
# 3                     NaN                   NaN       ...          False
# 4                     NaN                   NaN       ...          False
# 5                     NaN                   NaN       ...          False
# 6                     NaN                   NaN       ...          False
# 7                     NaN                   NaN       ...          False
# 8                     NaN                   NaN       ...          False
# 9                     NaN                   NaN       ...          False
# 10                    NaN                   NaN       ...          False
# 11                    NaN                   NaN       ...          False
# 12                    NaN                   NaN       ...          False
# 13                    NaN                   NaN       ...          False
# 14                    NaN                   NaN       ...          False
# 15                    NaN                   NaN       ...          False
# 16                    NaN                   NaN       ...          False
# 17                    NaN                   NaN       ...          False
# 18                    NaN                   NaN       ...          False
# 19                    NaN                   NaN       ...          False
#
#     playoff  score_home  score_away  home_win  fav_win  cover  spread_diff  \
# 0     False          13          19     False    False  False         -8.0
# 1     False          20          14      True    False    NaN          NaN
# 2     False          17          28     False    False    NaN          NaN
# 3     False          17          10      True    False    NaN          NaN
# 4     False          23          24     False    False    NaN          NaN
# 5     False          24           7      True    False    NaN          NaN
# 6     False          14           6      True    False    NaN          NaN
# 7     False           7          13     False    False    NaN          NaN
# 8     False          14          16     False    False    NaN          NaN
# 9     False          31          24      True    False    NaN          NaN
# 10    False          33          20      True    False    NaN          NaN
# 11    False          14          16     False    False    NaN          NaN
# 12    False          20          24     False    False    NaN          NaN
# 13    False          38           0      True    False    NaN          NaN
# 14    False           7          15     False    False    NaN          NaN
# 15    False           0          42     False    False    NaN          NaN
# 16    False          20          21     False    False    NaN          NaN
# 17    False          13          10      True    False    NaN          NaN
# 18    False          28          17      True    False    NaN          NaN
# 19    False          17          20     False    False    NaN          NaN
#
#     over_under_result  over_under_diff
# 0                 NaN              NaN
# 1                 NaN              NaN
# 2                 NaN              NaN
# 3                 NaN              NaN
# 4                 NaN              NaN
# 5                 NaN              NaN
# 6                 NaN              NaN
# 7                 NaN              NaN
# 8                 NaN              NaN
# 9                 NaN              NaN
# 10                NaN              NaN
# 11                NaN              NaN
# 12                NaN              NaN
# 13                NaN              NaN
# 14                NaN              NaN
# 15                NaN              NaN
# 16                NaN              NaN
# 17                NaN              NaN
# 18                NaN              NaN
# 19                NaN              NaN
#
# [20 rows x 30 columns]

# %%
data['season'].dtypes
# Out:
# dtype('int64')

# %%
data['over_under_diff'].describe()
# Out:
# count    9262.000000
# mean        0.619337
# std        13.682436
# min       -39.000000
# 25%        -9.000000
# 50%         0.000000
# 75%         9.500000
# max        68.500000
# Name: over_under_diff, dtype: float64

# %%
data['over_under_result'].describe()
# Out:
# count      9084
# unique        2
# top       Under
# freq       4605
# Name: over_under_result, dtype: object

# %%
data['spread_diff'].describe()
# Out:
# count    9122.000000
# mean       -0.121574
# std        13.388211
# min       -52.000000
# 25%        -8.500000
# 50%        -0.500000
# 75%         8.500000
# max        50.500000
# Name: spread_diff, dtype: float64

# %%
data['cover'].describe()
# Out:
# count      9122
# unique        2
# top       False
# freq       4831
# Name: cover, dtype: object
