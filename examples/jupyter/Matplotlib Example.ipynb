# %%
# %matplotlib inline

# %%
import matplotlib
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
from pylab import *

# %%
x = np.linspace(0, 5, 10)
y = x ** 2

# %%
subplot(1,2,1)
plot(x, y, 'r--')
subplot(1,2,2)
plot(y, x, 'g*-')
